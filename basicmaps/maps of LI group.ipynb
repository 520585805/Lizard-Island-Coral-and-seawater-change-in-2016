# %%
import os
import cartopy
import cartopy.crs as ccrs
cartopy.config['data_dir'] = os.getenv('CARTOPY_DIR', cartopy.config.get('data_dir'))
# Out:
# libarrow.so.900: cannot open shared object file: No such file or directory
# libarrow.so.900: cannot open shared object file: No such file or directory
# libpodofo.so.0.9.8: cannot open shared object file: No such file or directory
# libpodofo.so.0.9.8: cannot open shared object file: No such file or directory
# libarrow.so.900: cannot open shared object file: No such file or directory
# libarrow.so.900: cannot open shared object file: No such file or directory
# libarrow.so.900: cannot open shared object file: No such file or directory
# libarrow.so.900: cannot open shared object file: No such file or directory
# libpodofo.so.0.9.8: cannot open shared object file: No such file or directory
# libpodofo.so.0.9.8: cannot open shared object file: No such file or directory
# libarrow.so.900: cannot open shared object file: No such file or directory
# libarrow.so.900: cannot open shared object file: No such file or directory

# %%
ccrs.PlateCarree(0)
# Out:
# <Derived Projected CRS: +proj=eqc +ellps=WGS84 +a=6378137.0 +lon_0=0 +to_m ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (unknown)
# - N[north]: Northing (unknown)
# - h[up]: Ellipsoidal height (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Equidistant Cylindrical
# Datum: unknown
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ccrs.Mercator?

# %%
import cartopy.feature as cfeature
import numpy as np

extent = [112, 154, -44, -9]

largeview = ccrs.Mercator(central_longitude=132)

plt.figure(figsize=(3, 2.5))
ax = plt.axes(projection=largeview)
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)
ax.stock_img()

# %%
fig = plt.figure(figsize=(8, 12))


fname = 'LIgroup.png'

img = plt.imread(fname)
ax.imshow(img) #, origin='upper', transform=ccrs.Mercator(central_longitude=145.5))

# %%
import matplotlib.image as mpimg

img_extent = (145.1195, 145.80, -15.0415, -14.3740)

img = mpimg.imread('LI group.png')
imgplot = plt.imshow(img)
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))

# this is from the cartopy docs
fname = 'LI group.png'
img_extent = (145.1195, 145.80, -15.0415, -14.3740)

img = plt.imread(fname)

ax = plt.axes(projection=ccrs.PlateCarree())

# set a margin around the data
ax.set_xmargin(0.05)
ax.set_ymargin(0.10)

# gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
#                   linewidth=0.1, color='k', alpha=1, 
#                   linestyle='--')
# gl.top_labels = False
# gl.right_labels = False
# gl.xformatter = LONGITUDE_FORMATTER
# gl.yformatter = LATITUDE_FORMATTER
# gl.xlabel_style = {'size': 8}
# gl.ylabel_style = {'size': 8} 

# ax.plot(-145.4594, -14.6688, 'bo', markersize=7, transform=ccrs.PlateCarree())
# ax.text(-145, -14, 'Lizard Island', transform=ccrs.PlateCarree())

# add the image. Because this image was a tif, the "origin" of the image is in the
# upper left corner
ax.imshow(img, origin='upper', extent=img_extent, transform=ccrs.PlateCarree())
# ax.coastlines(resolution='10m', color='red', linewidth=3)

# %%
import cartopy.feature as cfeature
import numpy as np

extent = [145, 146, -15, -14]

largeview = ccrs.Mercator(central_longitude=145.5)

plt.figure(figsize=(10, 10))
ax = plt.axes(projection=largeview)
ax.set_extent(extent)

fname = 'LI group.png'

img = plt.imread(fname)
ax.imshow(img, origin='upper', transform=ccrs.Mercator(central_longitude=145.5))

#ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(cartopy.feature.BORDERS)
ax.gridlines()
# Out:
# Exception ignored in: <function BaseGeometry.__del__ at 0x7f605420bac0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/site-packages/shapely/geometry/base.py", line 210, in __del__
#     self.__p__ = None
#   File "/usr/lib/python3.10/site-packages/shapely/geometry/base.py", line 250, in __setattr__
#     super().__setattr__(name, value)
# KeyboardInterrupt:

# %%
ax.gridlines?
